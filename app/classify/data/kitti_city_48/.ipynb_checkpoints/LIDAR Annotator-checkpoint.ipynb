# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
# %matplotlib notebook
# %matplotlib notebook

# %%
PATH = './2011_09_26_drive_0048_sync/velodyne_points/data/'

# %%
a = np.fromfile(PATH + '0000000003.bin', dtype=np.float32).reshape((-1, 4))

# %%
a[:15]
# Out:
# array([[  7.88069992e+01,   6.12599993e+00,   2.88199997e+00,
#           0.00000000e+00],
#        [  7.90930023e+01,   6.27299976e+00,   2.89199996e+00,
#           0.00000000e+00],
#        [  7.85800018e+01,   6.48099995e+00,   2.87500000e+00,
#           0.00000000e+00],
#        [  7.90360031e+01,   6.76900005e+00,   2.89100003e+00,
#           0.00000000e+00],
#        [  7.91119995e+01,   7.02600002e+00,   2.89499998e+00,
#           0.00000000e+00],
#        [  7.85859985e+01,   7.22800016e+00,   2.87800002e+00,
#           0.00000000e+00],
#        [  7.84570007e+01,   7.46400023e+00,   2.87400007e+00,
#           0.00000000e+00],
#        [  7.84990005e+01,   7.71700001e+00,   2.87599993e+00,
#           0.00000000e+00],
#        [  7.91470032e+01,   7.90700006e+00,   2.89899993e+00,
#           0.00000000e+00],
#        [  7.82829971e+01,   8.06900024e+00,   2.86999989e+00,
#           0.00000000e+00],
#        [  7.82330017e+01,   8.31200027e+00,   2.86899996e+00,
#           0.00000000e+00],
#        [  5.11510010e+01,   7.54899979e+00,   1.95799994e+00,
#           0.00000000e+00],
#        [  5.02989998e+01,   7.58400011e+00,   1.92900002e+00,
#           0.00000000e+00],
#        [  4.94959984e+01,   7.62200022e+00,   1.90300000e+00,
#           0.00000000e+00],
#        [  5.14290009e+01,   8.08600044e+00,   1.97000003e+00,
#           5.00000007e-02]], dtype=float32)

# %%
a_trunc = a[:1000]

# %%
x, y, z = a_trunc[:,0], a_trunc[:,1], a_trunc[:,2]

# %%
x.shape
# Out:
# (1000,)

# %%
width, height = plt.figaspect(.5)
fig = plt.figure(figsize = (width, height))
ax = fig.add_subplot(111, projection='3d')
ax.scatter(x, y, z, zdir='z', c= 'red')
# plt.savefig("demo.png")

# %%
plt.plot(x, y)
